# %% [markdown]
# ## Small Ham

# %%
import h5py
import numpy as np
import os
import json
import json
import re
from convert import parseNpyEntry


for file in os.listdir('/Users/brendonuzoigwe/spherical-mds/new_data/hamiltonian_small_mat'):
    if len(os.listdir('/Users/brendonuzoigwe/spherical-mds/10rad_data/small/hamiltonian')) == 1000:
        break
    open('adjacency_list.txt', 'w').close()
    adjacency_list = parseNpyEntry(f'/Users/brendonuzoigwe/spherical-mds/new_data/hamiltonian_small_mat/{file}' )
    os.system('python3 layout.py adjacency_list.txt')

    

    # Function to convert a .js file with single quotes into valid JSON
    def convert_js_to_json(js_file):
        with open(js_file, 'r') as file:
            content = file.read()
            
            # Remove the variable declaration (if present) and replace single quotes with double quotes
            content = re.sub(r'^\s*G\s*=\s*', '', content, flags=re.MULTILINE)
            json_content = content.replace("'", '"')
            
        return json_content

    # Convert and read the JS file
    js_file = 'webapp/data.js'  # Adjust the path to your file as necessary
    json_content = convert_js_to_json(js_file)


    G = json.loads(json_content)

    def lat_long_to_cartesian(lat, long, radius=10.0):
        lat_rad = np.radians(lat)
        long_rad = np.radians(long)
        x = radius * np.cos(lat_rad) * np.cos(long_rad)
        y = radius * np.cos(lat_rad) * np.sin(long_rad)
        z = radius * np.sin(lat_rad)
        return [x, y, z]


    positions = np.array([lat_long_to_cartesian(node['pos'][0], node['pos'][1]) for node in G['nodes']])

    # Create a list to hold all edge points
    graph_data = []

    for pos in positions:
        graph_data.append(pos)

    # Define the number of points to interpolate along each edge
    num_nodes = len(G['nodes'])
    num_edges = len(G['edges'])
    if num_edges + num_nodes > 2048:
        save_dir = '/Users/brendonuzoigwe/spherical-mds/big_data'
    else:
        save_dir = '/Users/brendonuzoigwe/spherical-mds/10rad_data/small/hamiltonian'
    
    num_edge_points = (2048 - num_nodes) // num_edges

    first = True
    # Add edges with interpolation
    for edge in G['edges']:
        node1 = int(edge['source'])
        node2 = int(edge['target'])
        
        # Ensure the indices are valid
        if node1 < len(positions) and node2 < len(positions):
            point1 = positions[node1]
            point2 = positions[node2]
            
            # Interpolate points between point1 and point2
            if first:
                temp_point = num_edge_points + ((2048 - num_nodes) % num_edges)
                num_edge_points = temp_point
                first = False
            else:
                num_edge_points = (2048 - num_nodes) // num_edges

            for t in np.linspace(0, 1, num_edge_points):
                interpolated_point = point1 * (1 - t) + point2 * t
                graph_data.append(interpolated_point)

    graph_data = np.array(graph_data)            

    file_name = os.path.splitext(file)[0] + '.h5'
    file_path = os.path.join(save_dir, file_name)

    with h5py.File(file_path, 'w') as h5file:
        h5file.create_dataset('data', data=graph_data) 
        h5file.create_dataset('labels', data=1)  
    open('adjacency_list.txt', 'w').close()  
print(len(os.listdir('/Users/brendonuzoigwe/spherical-mds/10rad_data/small/hamiltonian')))

# %% [markdown]
# ## Med Ham

# %%
import h5py
import numpy as np
import os
import json
import json
import re
from convert import parseNpyEntry


for file in os.listdir('/Users/brendonuzoigwe/spherical-mds/new_data/hamiltonian_medium_mat'):
    if len(os.listdir('/Users/brendonuzoigwe/spherical-mds/10rad_data/medium/hamiltonian')) == 2000:
        break
    open('adjacency_list.txt', 'w').close()
    adjacency_list = parseNpyEntry(f'/Users/brendonuzoigwe/spherical-mds/new_data/hamiltonian_medium_mat/{file}' )
    os.system('python3 layout.py adjacency_list.txt')

    

    # Function to convert a .js file with single quotes into valid JSON
    def convert_js_to_json(js_file):
        with open(js_file, 'r') as file:
            content = file.read()
            
            # Remove the variable declaration (if present) and replace single quotes with double quotes
            content = re.sub(r'^\s*G\s*=\s*', '', content, flags=re.MULTILINE)
            json_content = content.replace("'", '"')
            
        return json_content

    # Convert and read the JS file
    js_file = 'webapp/data.js'  # Adjust the path to your file as necessary
    json_content = convert_js_to_json(js_file)


    G = json.loads(json_content)

    def lat_long_to_cartesian(lat, long, radius=10.0):
        lat_rad = np.radians(lat)
        long_rad = np.radians(long)
        x = radius * np.cos(lat_rad) * np.cos(long_rad)
        y = radius * np.cos(lat_rad) * np.sin(long_rad)
        z = radius * np.sin(lat_rad)
        return [x, y, z]


    positions = np.array([lat_long_to_cartesian(node['pos'][0], node['pos'][1]) for node in G['nodes']])

    # Create a list to hold all edge points
    graph_data = []

    for pos in positions:
        graph_data.append(pos)

    # Define the number of points to interpolate along each edge
    num_nodes = len(G['nodes'])
    num_edges = len(G['edges'])
    if num_edges + num_nodes > 2048:
        save_dir = '/Users/brendonuzoigwe/spherical-mds/big_data'
    else:
        save_dir = '/Users/brendonuzoigwe/spherical-mds/10rad_data/medium/hamiltonian'
    
    num_edge_points = (2048 - num_nodes) // num_edges

    first = True
    # Add edges with interpolation
    for edge in G['edges']:
        node1 = int(edge['source'])
        node2 = int(edge['target'])
        
        # Ensure the indices are valid
        if node1 < len(positions) and node2 < len(positions):
            point1 = positions[node1]
            point2 = positions[node2]
            
            # Interpolate points between point1 and point2
            if first:
                temp_point = num_edge_points + ((2048 - num_nodes) % num_edges)
                num_edge_points = temp_point
                first = False
            else:
                num_edge_points = (2048 - num_nodes) // num_edges

            for t in np.linspace(0, 1, num_edge_points):
                interpolated_point = point1 * (1 - t) + point2 * t
                graph_data.append(interpolated_point)

    graph_data = np.array(graph_data)            

    file_name = os.path.splitext(file)[0] + '.h5'
    file_path = os.path.join(save_dir, file_name)

    with h5py.File(file_path, 'w') as h5file:
        h5file.create_dataset('data', data=graph_data) 
        h5file.create_dataset('labels', data=1)  
    open('adjacency_list.txt', 'w').close()  
print(len(os.listdir('/Users/brendonuzoigwe/spherical-mds/10rad_data/medium/hamiltonian')))

# %% [markdown]
# ## Small non

# %%
import h5py
import numpy as np
import os
import json
import json
import re
from convert import parseNpyEntry


for file in os.listdir('/Users/brendonuzoigwe/spherical-mds/new_data/non_hamiltonian_small_mat'):
    if len(os.listdir('/Users/brendonuzoigwe/spherical-mds/10rad_data/small/non_hamiltonian')) == 3000:
        break
    open('adjacency_list.txt', 'w').close()
    adjacency_list = parseNpyEntry(f'/Users/brendonuzoigwe/spherical-mds/new_data/non_hamiltonian_small_mat/{file}' )
    os.system('python3 layout.py adjacency_list.txt')

    

    # Function to convert a .js file with single quotes into valid JSON
    def convert_js_to_json(js_file):
        with open(js_file, 'r') as file:
            content = file.read()
            
            # Remove the variable declaration (if present) and replace single quotes with double quotes
            content = re.sub(r'^\s*G\s*=\s*', '', content, flags=re.MULTILINE)
            json_content = content.replace("'", '"')
            
        return json_content

    # Convert and read the JS file
    js_file = 'webapp/data.js'  # Adjust the path to your file as necessary
    json_content = convert_js_to_json(js_file)


    G = json.loads(json_content)

    def lat_long_to_cartesian(lat, long, radius=10.0):
        lat_rad = np.radians(lat)
        long_rad = np.radians(long)
        x = radius * np.cos(lat_rad) * np.cos(long_rad)
        y = radius * np.cos(lat_rad) * np.sin(long_rad)
        z = radius * np.sin(lat_rad)
        return [x, y, z]


    positions = np.array([lat_long_to_cartesian(node['pos'][0], node['pos'][1]) for node in G['nodes']])

    # Create a list to hold all edge points
    graph_data = []

    for pos in positions:
        graph_data.append(pos)

    # Define the number of points to interpolate along each edge
    num_nodes = len(G['nodes'])
    num_edges = len(G['edges'])
    if num_edges + num_nodes > 2048:
        save_dir = '/Users/brendonuzoigwe/spherical-mds/big_data'
    else:
        save_dir = '/Users/brendonuzoigwe/spherical-mds/10rad_data/small/non_hamiltonian'
    
    num_edge_points = (2048 - num_nodes) // num_edges

    first = True
    # Add edges with interpolation
    for edge in G['edges']:
        node1 = int(edge['source'])
        node2 = int(edge['target'])
        
        # Ensure the indices are valid
        if node1 < len(positions) and node2 < len(positions):
            point1 = positions[node1]
            point2 = positions[node2]
            
            # Interpolate points between point1 and point2
            if first:
                temp_point = num_edge_points + ((2048 - num_nodes) % num_edges)
                num_edge_points = temp_point
                first = False
            else:
                num_edge_points = (2048 - num_nodes) // num_edges

            for t in np.linspace(0, 1, num_edge_points):
                interpolated_point = point1 * (1 - t) + point2 * t
                graph_data.append(interpolated_point)

    graph_data = np.array(graph_data)            

    file_name = os.path.splitext(file)[0] + '.h5'
    file_path = os.path.join(save_dir, file_name)

    with h5py.File(file_path, 'w') as h5file:
        h5file.create_dataset('data', data=graph_data) 
        h5file.create_dataset('labels', data=2)  
    open('adjacency_list.txt', 'w').close()  
print(len(os.listdir('/Users/brendonuzoigwe/spherical-mds/10rad_data/small/non_hamiltonian')))

# %% [markdown]
# ## Med non

# %%
import h5py
import numpy as np
import os
import json
import json
import re
from convert import parseNpyEntry


for file in os.listdir('/Users/brendonuzoigwe/spherical-mds/new_data/non_hamiltonian_medium_mat'):
    if len(os.listdir('/Users/brendonuzoigwe/spherical-mds/10rad_data/medium/non_hamiltonian')) == 4000:
        break
    open('adjacency_list.txt', 'w').close()
    adjacency_list = parseNpyEntry(f'/Users/brendonuzoigwe/spherical-mds/new_data/non_hamiltonian_medium_mat/{file}' )
    os.system('python3 layout.py adjacency_list.txt')

    

    # Function to convert a .js file with single quotes into valid JSON
    def convert_js_to_json(js_file):
        with open(js_file, 'r') as file:
            content = file.read()
            
            # Remove the variable declaration (if present) and replace single quotes with double quotes
            content = re.sub(r'^\s*G\s*=\s*', '', content, flags=re.MULTILINE)
            json_content = content.replace("'", '"')
            
        return json_content

    # Convert and read the JS file
    js_file = 'webapp/data.js'  # Adjust the path to your file as necessary
    json_content = convert_js_to_json(js_file)


    G = json.loads(json_content)

    def lat_long_to_cartesian(lat, long, radius=10.0):
        lat_rad = np.radians(lat)
        long_rad = np.radians(long)
        x = radius * np.cos(lat_rad) * np.cos(long_rad)
        y = radius * np.cos(lat_rad) * np.sin(long_rad)
        z = radius * np.sin(lat_rad)
        return [x, y, z]


    positions = np.array([lat_long_to_cartesian(node['pos'][0], node['pos'][1]) for node in G['nodes']])

    # Create a list to hold all edge points
    graph_data = []

    for pos in positions:
        graph_data.append(pos)

    # Define the number of points to interpolate along each edge
    num_nodes = len(G['nodes'])
    num_edges = len(G['edges'])
    if num_edges + num_nodes > 2048:
        save_dir = '/Users/brendonuzoigwe/spherical-mds/big_data'
    else:
        save_dir = '/Users/brendonuzoigwe/spherical-mds/10rad_data/medium/non_hamiltonian'
    
    num_edge_points = (2048 - num_nodes) // num_edges

    first = True
    # Add edges with interpolation
    for edge in G['edges']:
        node1 = int(edge['source'])
        node2 = int(edge['target'])
        
        # Ensure the indices are valid
        if node1 < len(positions) and node2 < len(positions):
            point1 = positions[node1]
            point2 = positions[node2]
            
            # Interpolate points between point1 and point2
            if first:
                temp_point = num_edge_points + ((2048 - num_nodes) % num_edges)
                num_edge_points = temp_point
                first = False
            else:
                num_edge_points = (2048 - num_nodes) // num_edges

            for t in np.linspace(0, 1, num_edge_points):
                interpolated_point = point1 * (1 - t) + point2 * t
                graph_data.append(interpolated_point)

    graph_data = np.array(graph_data)            

    file_name = os.path.splitext(file)[0] + '.h5'
    file_path = os.path.join(save_dir, file_name)

    with h5py.File(file_path, 'w') as h5file:
        h5file.create_dataset('data', data=graph_data) 
        h5file.create_dataset('labels', data=2)  
    open('adjacency_list.txt', 'w').close()  
print(len(os.listdir('/Users/brendonuzoigwe/spherical-mds/10rad_data/medium/non_hamiltonian')))

# %% [markdown]
# ## Spherical layout

# %%
import h5py
import numpy as np
import os
import json
import re
from convert import parseNpyEntry

# Function to convert latitude and longitude to Cartesian coordinates
def lat_long_to_cartesian(lat, long, radius=1.0):
    lat_rad = np.radians(lat)
    long_rad = np.radians(long)
    x = radius * np.cos(lat_rad) * np.cos(long_rad)
    y = radius * np.cos(lat_rad) * np.sin(long_rad)
    z = radius * np.sin(lat_rad)
    return [x, y, z]

# Function to interpolate points along a great-circle path between two points
def interpolate_great_circle(p1, p2, num_points, radius=1.0):
    # Normalize the points
    p1 = p1 / np.linalg.norm(p1)
    p2 = p2 / np.linalg.norm(p2)
    
    # Calculate the angle between the two points
    angle = np.arccos(np.clip(np.dot(p1, p2), -1.0, 1.0))
    
    # Generate the interpolated points
    interpolated_points = []
    for t in np.linspace(0, 1, num_points):
        sin_angle = np.sin(angle)
        if sin_angle == 0:  # p1 and p2 are the same point
            interpolated_point = p1
        else:
            interpolated_point = (np.sin((1 - t) * angle) * p1 + np.sin(t * angle) * p2) / sin_angle
        # Scale the point back to the specified radius
        interpolated_points.append(radius * interpolated_point)
    
    return interpolated_points

for file in os.listdir('/Users/brendonuzoigwe/spherical-mds/new_data/hamiltonian_small_mat'):
    if len(os.listdir('/Users/brendonuzoigwe/spherical-mds/big_data')) == 1000:
        break
    open('adjacency_list.txt', 'w').close()
    adjacency_list = parseNpyEntry(f'/Users/brendonuzoigwe/spherical-mds/new_data/hamiltonian_small_mat/{file}')
    os.system('python3 layout.py adjacency_list.txt')

    # Function to convert a .js file with single quotes into valid JSON
    def convert_js_to_json(js_file):
        with open(js_file, 'r') as file:
            content = file.read()
            # Remove the variable declaration (if present) and replace single quotes with double quotes
            content = re.sub(r'^\s*G\s*=\s*', '', content, flags=re.MULTILINE)
            json_content = content.replace("'", '"')
        return json_content

    # Convert and read the JS file
    js_file = 'webapp/data.js'  # Adjust the path to your file as necessary
    json_content = convert_js_to_json(js_file)

    G = json.loads(json_content)

    # Convert node positions to Cartesian coordinates
    positions = np.array([lat_long_to_cartesian(node['pos'][0], node['pos'][1]) for node in G['nodes']])

    # Create a list to hold all graph data
    graph_data = []

    # Add node positions to graph_data
    for pos in positions:
        graph_data.append(pos)

    # Determine the number of edge points
    num_nodes = len(G['nodes'])
    num_edges = len(G['edges'])
    if num_edges + num_nodes <= 2048:
        save_dir = '/Users/brendonuzoigwe/spherical-mds/big_data'
    else:
        continue
    
    num_edge_points = (2048 - num_nodes) // num_edges
    first = True

    # Add edges with great-circle interpolation
    for edge in G['edges']:
        node1 = int(edge['source'])
        node2 = int(edge['target'])
        
        # Ensure the indices are valid
        if node1 < len(positions) and node2 < len(positions):
            point1 = positions[node1]
            point2 = positions[node2]
            
            # Determine the number of points for this edge
            if first:
                temp_point = num_edge_points + ((2048 - num_nodes) % num_edges)
                num_edge_points = temp_point
                first = False
            else:
                num_edge_points = (2048 - num_nodes) // num_edges
            
            # Interpolate along the great-circle path
            interpolated_points = interpolate_great_circle(point1, point2, num_edge_points)
            graph_data.extend(interpolated_points)

    # Convert graph_data to a numpy array
    graph_data = np.array(graph_data)

    # Save the graph data in an HDF5 file
    file_name = os.path.splitext(file)[0] + '_small.h5'
    file_path = os.path.join(save_dir, file_name)

    with h5py.File(file_path, 'w') as h5file:
        h5file.create_dataset('data', data=graph_data)
        h5file.create_dataset('labels', data=1)
    
    open('adjacency_list.txt', 'w').close()

print(len(os.listdir('/Users/brendonuzoigwe/spherical-mds/big_data')))

# %%
import h5py
import numpy as np
import os
import json
import re
from convert import parseNpyEntry

# Function to convert latitude and longitude to Cartesian coordinates
def lat_long_to_cartesian(lat, long, radius=1.0):
    lat_rad = np.radians(lat)
    long_rad = np.radians(long)
    x = radius * np.cos(lat_rad) * np.cos(long_rad)
    y = radius * np.cos(lat_rad) * np.sin(long_rad)
    z = radius * np.sin(lat_rad)
    return [x, y, z]

# Function to interpolate points along a great-circle path between two points
def interpolate_great_circle(p1, p2, num_points, radius=1.0):
    # Normalize the points
    p1 = p1 / np.linalg.norm(p1)
    p2 = p2 / np.linalg.norm(p2)
    
    # Calculate the angle between the two points
    angle = np.arccos(np.clip(np.dot(p1, p2), -1.0, 1.0))
    
    # Generate the interpolated points
    interpolated_points = []
    for t in np.linspace(0, 1, num_points):
        sin_angle = np.sin(angle)
        if sin_angle == 0:  # p1 and p2 are the same point
            interpolated_point = p1
        else:
            interpolated_point = (np.sin((1 - t) * angle) * p1 + np.sin(t * angle) * p2) / sin_angle
        # Scale the point back to the specified radius
        interpolated_points.append(radius * interpolated_point)
    
    return interpolated_points

for file in os.listdir('/Users/brendonuzoigwe/spherical-mds/new_data/hamiltonian_medium_mat'):
    if len(os.listdir('/Users/brendonuzoigwe/spherical-mds/big_data')) == 2000:
        break
    open('adjacency_list.txt', 'w').close()
    adjacency_list = parseNpyEntry(f'/Users/brendonuzoigwe/spherical-mds/new_data/hamiltonian_medium_mat/{file}')
    os.system('python3 layout.py adjacency_list.txt')

    # Function to convert a .js file with single quotes into valid JSON
    def convert_js_to_json(js_file):
        with open(js_file, 'r') as file:
            content = file.read()
            # Remove the variable declaration (if present) and replace single quotes with double quotes
            content = re.sub(r'^\s*G\s*=\s*', '', content, flags=re.MULTILINE)
            json_content = content.replace("'", '"')
        return json_content

    # Convert and read the JS file
    js_file = 'webapp/data.js'  # Adjust the path to your file as necessary
    json_content = convert_js_to_json(js_file)

    G = json.loads(json_content)

    # Convert node positions to Cartesian coordinates
    positions = np.array([lat_long_to_cartesian(node['pos'][0], node['pos'][1]) for node in G['nodes']])

    # Create a list to hold all graph data
    graph_data = []

    # Add node positions to graph_data
    for pos in positions:
        graph_data.append(pos)

    # Determine the number of edge points
    num_nodes = len(G['nodes'])
    num_edges = len(G['edges'])
    if num_edges + num_nodes <= 2048:
        save_dir = '/Users/brendonuzoigwe/spherical-mds/big_data'
    else:
        continue
    
    num_edge_points = (2048 - num_nodes) // num_edges
    first = True

    # Add edges with great-circle interpolation
    for edge in G['edges']:
        node1 = int(edge['source'])
        node2 = int(edge['target'])
        
        # Ensure the indices are valid
        if node1 < len(positions) and node2 < len(positions):
            point1 = positions[node1]
            point2 = positions[node2]
            
            # Determine the number of points for this edge
            if first:
                temp_point = num_edge_points + ((2048 - num_nodes) % num_edges)
                num_edge_points = temp_point
                first = False
            else:
                num_edge_points = (2048 - num_nodes) // num_edges
            
            # Interpolate along the great-circle path
            interpolated_points = interpolate_great_circle(point1, point2, num_edge_points)
            graph_data.extend(interpolated_points)

    # Convert graph_data to a numpy array
    graph_data = np.array(graph_data)

    # Save the graph data in an HDF5 file
    file_name = os.path.splitext(file)[0] + '_medium.h5'
    file_path = os.path.join(save_dir, file_name)

    with h5py.File(file_path, 'w') as h5file:
        h5file.create_dataset('data', data=graph_data)
        h5file.create_dataset('labels', data=1)
    
    open('adjacency_list.txt', 'w').close()

print(len(os.listdir('/Users/brendonuzoigwe/spherical-mds/big_data')))

# %%
import h5py
import numpy as np
import os
import json
import re
from convert import parseNpyEntry

# Function to convert latitude and longitude to Cartesian coordinates
def lat_long_to_cartesian(lat, long, radius=1.0):
    lat_rad = np.radians(lat)
    long_rad = np.radians(long)
    x = radius * np.cos(lat_rad) * np.cos(long_rad)
    y = radius * np.cos(lat_rad) * np.sin(long_rad)
    z = radius * np.sin(lat_rad)
    return [x, y, z]

# Function to interpolate points along a great-circle path between two points
def interpolate_great_circle(p1, p2, num_points, radius=1.0):
    # Normalize the points
    p1 = p1 / np.linalg.norm(p1)
    p2 = p2 / np.linalg.norm(p2)
    
    # Calculate the angle between the two points
    angle = np.arccos(np.clip(np.dot(p1, p2), -1.0, 1.0))
    
    # Generate the interpolated points
    interpolated_points = []
    for t in np.linspace(0, 1, num_points):
        sin_angle = np.sin(angle)
        if sin_angle == 0:  # p1 and p2 are the same point
            interpolated_point = p1
        else:
            interpolated_point = (np.sin((1 - t) * angle) * p1 + np.sin(t * angle) * p2) / sin_angle
        # Scale the point back to the specified radius
        interpolated_points.append(radius * interpolated_point)
    
    return interpolated_points

for file in os.listdir('/Users/brendonuzoigwe/spherical-mds/new_data/non_hamiltonian_small_mat'):
    if len(os.listdir('/Users/brendonuzoigwe/spherical-mds/big_data')) == 3000:
        break
    open('adjacency_list.txt', 'w').close()
    adjacency_list = parseNpyEntry(f'/Users/brendonuzoigwe/spherical-mds/new_data/non_hamiltonian_small_mat/{file}')
    os.system('python3 layout.py adjacency_list.txt')

    # Function to convert a .js file with single quotes into valid JSON
    def convert_js_to_json(js_file):
        with open(js_file, 'r') as file:
            content = file.read()
            # Remove the variable declaration (if present) and replace single quotes with double quotes
            content = re.sub(r'^\s*G\s*=\s*', '', content, flags=re.MULTILINE)
            json_content = content.replace("'", '"')
        return json_content

    # Convert and read the JS file
    js_file = 'webapp/data.js'  # Adjust the path to your file as necessary
    json_content = convert_js_to_json(js_file)

    G = json.loads(json_content)

    # Convert node positions to Cartesian coordinates
    positions = np.array([lat_long_to_cartesian(node['pos'][0], node['pos'][1]) for node in G['nodes']])

    # Create a list to hold all graph data
    graph_data = []

    # Add node positions to graph_data
    for pos in positions:
        graph_data.append(pos)

    # Determine the number of edge points
    num_nodes = len(G['nodes'])
    num_edges = len(G['edges'])
    if num_edges + num_nodes <= 2048:
        save_dir = '/Users/brendonuzoigwe/spherical-mds/big_data'
    else:
        continue
    
    num_edge_points = (2048 - num_nodes) // num_edges
    first = True

    # Add edges with great-circle interpolation
    for edge in G['edges']:
        node1 = int(edge['source'])
        node2 = int(edge['target'])
        
        # Ensure the indices are valid
        if node1 < len(positions) and node2 < len(positions):
            point1 = positions[node1]
            point2 = positions[node2]
            
            # Determine the number of points for this edge
            if first:
                temp_point = num_edge_points + ((2048 - num_nodes) % num_edges)
                num_edge_points = temp_point
                first = False
            else:
                num_edge_points = (2048 - num_nodes) // num_edges
            
            # Interpolate along the great-circle path
            interpolated_points = interpolate_great_circle(point1, point2, num_edge_points)
            graph_data.extend(interpolated_points)

    # Convert graph_data to a numpy array
    graph_data = np.array(graph_data)

    # Save the graph data in an HDF5 file
    file_name = os.path.splitext(file)[0] + '_small.h5'
    file_path = os.path.join(save_dir, file_name)

    with h5py.File(file_path, 'w') as h5file:
        h5file.create_dataset('data', data=graph_data)
        h5file.create_dataset('labels', data=2)
    
    open('adjacency_list.txt', 'w').close()

print(len(os.listdir('/Users/brendonuzoigwe/spherical-mds/big_data')))

# %%
import h5py
import numpy as np
import os
import json
import re
from convert import parseNpyEntry

# Function to convert latitude and longitude to Cartesian coordinates
def lat_long_to_cartesian(lat, long, radius=1.0):
    lat_rad = np.radians(lat)
    long_rad = np.radians(long)
    x = radius * np.cos(lat_rad) * np.cos(long_rad)
    y = radius * np.cos(lat_rad) * np.sin(long_rad)
    z = radius * np.sin(lat_rad)
    return [x, y, z]

# Function to interpolate points along a great-circle path between two points
def interpolate_great_circle(p1, p2, num_points, radius=1.0):
    # Normalize the points
    p1 = p1 / np.linalg.norm(p1)
    p2 = p2 / np.linalg.norm(p2)
    
    # Calculate the angle between the two points
    angle = np.arccos(np.clip(np.dot(p1, p2), -1.0, 1.0))
    
    # Generate the interpolated points
    interpolated_points = []
    for t in np.linspace(0, 1, num_points):
        sin_angle = np.sin(angle)
        if sin_angle == 0:  # p1 and p2 are the same point
            interpolated_point = p1
        else:
            interpolated_point = (np.sin((1 - t) * angle) * p1 + np.sin(t * angle) * p2) / sin_angle
        # Scale the point back to the specified radius
        interpolated_points.append(radius * interpolated_point)
    
    return interpolated_points

for file in os.listdir('/Users/brendonuzoigwe/spherical-mds/new_data/non_hamiltonian_medium_mat'):
    if len(os.listdir('/Users/brendonuzoigwe/spherical-mds/big_data')) == 4000:
        break
    open('adjacency_list.txt', 'w').close()
    adjacency_list = parseNpyEntry(f'/Users/brendonuzoigwe/spherical-mds/new_data/non_hamiltonian_medium_mat/{file}')
    os.system('python3 layout.py adjacency_list.txt')

    # Function to convert a .js file with single quotes into valid JSON
    def convert_js_to_json(js_file):
        with open(js_file, 'r') as file:
            content = file.read()
            # Remove the variable declaration (if present) and replace single quotes with double quotes
            content = re.sub(r'^\s*G\s*=\s*', '', content, flags=re.MULTILINE)
            json_content = content.replace("'", '"')
        return json_content

    # Convert and read the JS file
    js_file = 'webapp/data.js'  # Adjust the path to your file as necessary
    json_content = convert_js_to_json(js_file)

    G = json.loads(json_content)

    # Convert node positions to Cartesian coordinates
    positions = np.array([lat_long_to_cartesian(node['pos'][0], node['pos'][1]) for node in G['nodes']])

    # Create a list to hold all graph data
    graph_data = []

    # Add node positions to graph_data
    for pos in positions:
        graph_data.append(pos)

    # Determine the number of edge points
    num_nodes = len(G['nodes'])
    num_edges = len(G['edges'])
    if num_edges + num_nodes <= 2048:
        save_dir = '/Users/brendonuzoigwe/spherical-mds/big_data'
    else:
        continue
    
    num_edge_points = (2048 - num_nodes) // num_edges
    first = True

    # Add edges with great-circle interpolation
    for edge in G['edges']:
        node1 = int(edge['source'])
        node2 = int(edge['target'])
        
        # Ensure the indices are valid
        if node1 < len(positions) and node2 < len(positions):
            point1 = positions[node1]
            point2 = positions[node2]
            
            # Determine the number of points for this edge
            if first:
                temp_point = num_edge_points + ((2048 - num_nodes) % num_edges)
                num_edge_points = temp_point
                first = False
            else:
                num_edge_points = (2048 - num_nodes) // num_edges
            
            # Interpolate along the great-circle path
            interpolated_points = interpolate_great_circle(point1, point2, num_edge_points)
            graph_data.extend(interpolated_points)

    # Convert graph_data to a numpy array
    graph_data = np.array(graph_data)

    # Save the graph data in an HDF5 file
    file_name = os.path.splitext(file)[0] + '_medium.h5'
    file_path = os.path.join(save_dir, file_name)

    with h5py.File(file_path, 'w') as h5file:
        h5file.create_dataset('data', data=graph_data)
        h5file.create_dataset('labels', data=2)
    
    open('adjacency_list.txt', 'w').close()

print(len(os.listdir('/Users/brendonuzoigwe/spherical-mds/big_data')))

# %% [markdown]
# ## Clustered nodes

# %%
import h5py
import numpy as np
import os
import json
import re
from convert import parseNpyEntry

# Function to convert latitude and longitude to Cartesian coordinates
def lat_long_to_cartesian(lat, long, radius=1.0):
    lat_rad = np.radians(lat)
    long_rad = np.radians(long)
    x = radius * np.cos(lat_rad) * np.cos(long_rad)
    y = radius * np.cos(lat_rad) * np.sin(long_rad)
    z = radius * np.sin(lat_rad)
    return [x, y, z]

# Function to interpolate points along a great-circle path between two points
def interpolate_great_circle(p1, p2, num_points, radius=1.0):
    p1 = p1 / np.linalg.norm(p1)
    p2 = p2 / np.linalg.norm(p2)
    angle = np.arccos(np.clip(np.dot(p1, p2), -1.0, 1.0))
    
    interpolated_points = []
    for t in np.linspace(0, 1, num_points):
        sin_angle = np.sin(angle)
        if sin_angle == 0:  # p1 and p2 are the same point
            interpolated_point = p1
        else:
            interpolated_point = (np.sin((1 - t) * angle) * p1 + np.sin(t * angle) * p2) / sin_angle
        interpolated_points.append(radius * interpolated_point)
    
    return interpolated_points

# Function to generate a cluster of points around a given position
def generate_node_cluster(center, num_points, cluster_radius=0.03):
    cluster_points = []
    for _ in range(num_points):
        theta = np.random.uniform(0, 2 * np.pi)
        phi = np.random.uniform(0, np.pi)
        r = np.random.uniform(0, cluster_radius)
        
        x = r * np.sin(phi) * np.cos(theta)
        y = r * np.sin(phi) * np.sin(theta)
        z = r * np.cos(phi)
        
        cluster_point = center + np.array([x, y, z])
        cluster_points.append(cluster_point)
    
    return cluster_points

for file in os.listdir('/Users/brendonuzoigwe/spherical-mds/new_data/hamiltonian_small_mat'):
    if len(os.listdir('/Users/brendonuzoigwe/spherical-mds/cluster_data')) == 1000:
        break
    open('adjacency_list.txt', 'w').close()
    adjacency_list = parseNpyEntry(f'/Users/brendonuzoigwe/spherical-mds/new_data/hamiltonian_small_mat/{file}')
    os.system('python3 layout.py adjacency_list.txt')

    def convert_js_to_json(js_file):
        with open(js_file, 'r') as file:
            content = file.read()
            content = re.sub(r'^\s*G\s*=\s*', '', content, flags=re.MULTILINE)
            json_content = content.replace("'", '"')
        return json_content

    js_file = 'webapp/data.js'
    json_content = convert_js_to_json(js_file)

    G = json.loads(json_content)
    positions = np.array([lat_long_to_cartesian(node['pos'][0], node['pos'][1]) for node in G['nodes']])

    graph_data = []

    # Add node clusters
    num_cluster_points = 10
    for pos in positions:
        graph_data.append(pos)
        cluster_points = generate_node_cluster(pos, num_cluster_points)
        graph_data.extend(cluster_points)

    num_nodes = len(G['nodes'])
    num_edges = len(G['edges'])
    if num_edges + num_nodes + num_cluster_points * num_nodes <= 2048:
        save_dir = '/Users/brendonuzoigwe/spherical-mds/cluster_data'
    else:
        continue
    
    num_edge_points = (2048 - num_nodes - num_cluster_points * num_nodes) // num_edges
    first = True

    for edge in G['edges']:
        node1 = int(edge['source'])
        node2 = int(edge['target'])
        
        if node1 < len(positions) and node2 < len(positions):
            point1 = positions[node1]
            point2 = positions[node2]
            
            if first:
                temp_point = num_edge_points + ((2048 - num_nodes) % num_edges)
                num_edge_points = temp_point
                first = False
            else:
                num_edge_points = (2048 - num_nodes) // num_edges
            
            interpolated_points = interpolate_great_circle(point1, point2, num_edge_points)
            graph_data.extend(interpolated_points)

    graph_data = np.array(graph_data)

    file_name = os.path.splitext(file)[0] + '_small.h5'
    file_path = os.path.join(save_dir, file_name)

    with h5py.File(file_path, 'w') as h5file:
        h5file.create_dataset('data', data=graph_data)
        h5file.create_dataset('labels', data=1)
    
    open('adjacency_list.txt', 'w').close()

print(len(os.listdir('/Users/brendonuzoigwe/spherical-mds/cluster_data')))

# %%
import h5py
import numpy as np
import os
import json
import re
from convert import parseNpyEntry

# Function to convert latitude and longitude to Cartesian coordinates
def lat_long_to_cartesian(lat, long, radius=1.0):
    lat_rad = np.radians(lat)
    long_rad = np.radians(long)
    x = radius * np.cos(lat_rad) * np.cos(long_rad)
    y = radius * np.cos(lat_rad) * np.sin(long_rad)
    z = radius * np.sin(lat_rad)
    return [x, y, z]

# Function to interpolate points along a great-circle path between two points
def interpolate_great_circle(p1, p2, num_points, radius=1.0):
    p1 = p1 / np.linalg.norm(p1)
    p2 = p2 / np.linalg.norm(p2)
    angle = np.arccos(np.clip(np.dot(p1, p2), -1.0, 1.0))
    
    interpolated_points = []
    for t in np.linspace(0, 1, num_points):
        sin_angle = np.sin(angle)
        if sin_angle == 0:  # p1 and p2 are the same point
            interpolated_point = p1
        else:
            interpolated_point = (np.sin((1 - t) * angle) * p1 + np.sin(t * angle) * p2) / sin_angle
        interpolated_points.append(radius * interpolated_point)
    
    return interpolated_points

# Function to generate a cluster of points around a given position
def generate_node_cluster(center, num_points, cluster_radius=0.03):
    cluster_points = []
    for _ in range(num_points):
        theta = np.random.uniform(0, 2 * np.pi)
        phi = np.random.uniform(0, np.pi)
        r = np.random.uniform(0, cluster_radius)
        
        x = r * np.sin(phi) * np.cos(theta)
        y = r * np.sin(phi) * np.sin(theta)
        z = r * np.cos(phi)
        
        cluster_point = center + np.array([x, y, z])
        cluster_points.append(cluster_point)
    
    return cluster_points

for file in os.listdir('/Users/brendonuzoigwe/spherical-mds/new_data/hamiltonian_medium_mat'):
    if len(os.listdir('/Users/brendonuzoigwe/spherical-mds/cluster_data')) == 2000:
        break
    open('adjacency_list.txt', 'w').close()
    adjacency_list = parseNpyEntry(f'/Users/brendonuzoigwe/spherical-mds/new_data/hamiltonian_medium_mat/{file}')
    os.system('python3 layout.py adjacency_list.txt')

    def convert_js_to_json(js_file):
        with open(js_file, 'r') as file:
            content = file.read()
            content = re.sub(r'^\s*G\s*=\s*', '', content, flags=re.MULTILINE)
            json_content = content.replace("'", '"')
        return json_content

    js_file = 'webapp/data.js'
    json_content = convert_js_to_json(js_file)

    G = json.loads(json_content)
    positions = np.array([lat_long_to_cartesian(node['pos'][0], node['pos'][1]) for node in G['nodes']])

    graph_data = []

    # Add node clusters
    num_cluster_points = 10
    for pos in positions:
        graph_data.append(pos)
        cluster_points = generate_node_cluster(pos, num_cluster_points)
        graph_data.extend(cluster_points)

    num_nodes = len(G['nodes'])
    num_edges = len(G['edges'])
    if num_edges + num_nodes + num_cluster_points * num_nodes <= 2048:
        save_dir = '/Users/brendonuzoigwe/spherical-mds/cluster_data'
    else:
        continue
    
    num_edge_points = (2048 - num_nodes - num_cluster_points * num_nodes) // num_edges
    first = True

    for edge in G['edges']:
        node1 = int(edge['source'])
        node2 = int(edge['target'])
        
        if node1 < len(positions) and node2 < len(positions):
            point1 = positions[node1]
            point2 = positions[node2]
            
            if first:
                temp_point = num_edge_points + ((2048 - num_nodes) % num_edges)
                num_edge_points = temp_point
                first = False
            else:
                num_edge_points = (2048 - num_nodes) // num_edges
            
            interpolated_points = interpolate_great_circle(point1, point2, num_edge_points)
            graph_data.extend(interpolated_points)

    graph_data = np.array(graph_data)

    file_name = os.path.splitext(file)[0] + '_medium.h5'
    file_path = os.path.join(save_dir, file_name)

    with h5py.File(file_path, 'w') as h5file:
        h5file.create_dataset('data', data=graph_data)
        h5file.create_dataset('labels', data=1)
    
    open('adjacency_list.txt', 'w').close()

print(len(os.listdir('/Users/brendonuzoigwe/spherical-mds/cluster_data')))

# %%
import h5py
import numpy as np
import os
import json
import re
from convert import parseNpyEntry

# Function to convert latitude and longitude to Cartesian coordinates
def lat_long_to_cartesian(lat, long, radius=1.0):
    lat_rad = np.radians(lat)
    long_rad = np.radians(long)
    x = radius * np.cos(lat_rad) * np.cos(long_rad)
    y = radius * np.cos(lat_rad) * np.sin(long_rad)
    z = radius * np.sin(lat_rad)
    return [x, y, z]

# Function to interpolate points along a great-circle path between two points
def interpolate_great_circle(p1, p2, num_points, radius=1.0):
    p1 = p1 / np.linalg.norm(p1)
    p2 = p2 / np.linalg.norm(p2)
    angle = np.arccos(np.clip(np.dot(p1, p2), -1.0, 1.0))
    
    interpolated_points = []
    for t in np.linspace(0, 1, num_points):
        sin_angle = np.sin(angle)
        if sin_angle == 0:  # p1 and p2 are the same point
            interpolated_point = p1
        else:
            interpolated_point = (np.sin((1 - t) * angle) * p1 + np.sin(t * angle) * p2) / sin_angle
        interpolated_points.append(radius * interpolated_point)
    
    return interpolated_points

# Function to generate a cluster of points around a given position
def generate_node_cluster(center, num_points, cluster_radius=0.03):
    cluster_points = []
    for _ in range(num_points):
        theta = np.random.uniform(0, 2 * np.pi)
        phi = np.random.uniform(0, np.pi)
        r = np.random.uniform(0, cluster_radius)
        
        x = r * np.sin(phi) * np.cos(theta)
        y = r * np.sin(phi) * np.sin(theta)
        z = r * np.cos(phi)
        
        cluster_point = center + np.array([x, y, z])
        cluster_points.append(cluster_point)
    
    return cluster_points

for file in os.listdir('/Users/brendonuzoigwe/spherical-mds/new_data/non_hamiltonian_small_mat'):
    if len(os.listdir('/Users/brendonuzoigwe/spherical-mds/cluster_data')) == 3000:
        break
    open('adjacency_list.txt', 'w').close()
    adjacency_list = parseNpyEntry(f'/Users/brendonuzoigwe/spherical-mds/new_data/non_hamiltonian_small_mat/{file}')
    os.system('python3 layout.py adjacency_list.txt')

    def convert_js_to_json(js_file):
        with open(js_file, 'r') as file:
            content = file.read()
            content = re.sub(r'^\s*G\s*=\s*', '', content, flags=re.MULTILINE)
            json_content = content.replace("'", '"')
        return json_content

    js_file = 'webapp/data.js'
    json_content = convert_js_to_json(js_file)

    G = json.loads(json_content)
    positions = np.array([lat_long_to_cartesian(node['pos'][0], node['pos'][1]) for node in G['nodes']])

    graph_data = []

    # Add node clusters
    num_cluster_points = 10
    for pos in positions:
        graph_data.append(pos)
        cluster_points = generate_node_cluster(pos, num_cluster_points)
        graph_data.extend(cluster_points)

    num_nodes = len(G['nodes'])
    num_edges = len(G['edges'])
    if num_edges + num_nodes + num_cluster_points * num_nodes <= 2048:
        save_dir = '/Users/brendonuzoigwe/spherical-mds/cluster_data'
    else:
        continue
    
    num_edge_points = (2048 - num_nodes - num_cluster_points * num_nodes) // num_edges
    first = True

    for edge in G['edges']:
        node1 = int(edge['source'])
        node2 = int(edge['target'])
        
        if node1 < len(positions) and node2 < len(positions):
            point1 = positions[node1]
            point2 = positions[node2]
            
            if first:
                temp_point = num_edge_points + ((2048 - num_nodes) % num_edges)
                num_edge_points = temp_point
                first = False
            else:
                num_edge_points = (2048 - num_nodes) // num_edges
            
            interpolated_points = interpolate_great_circle(point1, point2, num_edge_points)
            graph_data.extend(interpolated_points)

    graph_data = np.array(graph_data)

    file_name = os.path.splitext(file)[0] + '_small.h5'
    file_path = os.path.join(save_dir, file_name)

    with h5py.File(file_path, 'w') as h5file:
        h5file.create_dataset('data', data=graph_data)
        h5file.create_dataset('labels', data=1)
    
    open('adjacency_list.txt', 'w').close()

print(len(os.listdir('/Users/brendonuzoigwe/spherical-mds/cluster_data')))

# %%
import h5py
import numpy as np
import os
import json
import re
from convert import parseNpyEntry

# Function to convert latitude and longitude to Cartesian coordinates
def lat_long_to_cartesian(lat, long, radius=1.0):
    lat_rad = np.radians(lat)
    long_rad = np.radians(long)
    x = radius * np.cos(lat_rad) * np.cos(long_rad)
    y = radius * np.cos(lat_rad) * np.sin(long_rad)
    z = radius * np.sin(lat_rad)
    return [x, y, z]

# Function to interpolate points along a great-circle path between two points
def interpolate_great_circle(p1, p2, num_points, radius=1.0):
    p1 = p1 / np.linalg.norm(p1)
    p2 = p2 / np.linalg.norm(p2)
    angle = np.arccos(np.clip(np.dot(p1, p2), -1.0, 1.0))
    
    interpolated_points = []
    for t in np.linspace(0, 1, num_points):
        sin_angle = np.sin(angle)
        if sin_angle == 0:  # p1 and p2 are the same point
            interpolated_point = p1
        else:
            interpolated_point = (np.sin((1 - t) * angle) * p1 + np.sin(t * angle) * p2) / sin_angle
        interpolated_points.append(radius * interpolated_point)
    
    return interpolated_points

# Function to generate a cluster of points around a given position
def generate_node_cluster(center, num_points, cluster_radius=0.03):
    cluster_points = []
    for _ in range(num_points):
        theta = np.random.uniform(0, 2 * np.pi)
        phi = np.random.uniform(0, np.pi)
        r = np.random.uniform(0, cluster_radius)
        
        x = r * np.sin(phi) * np.cos(theta)
        y = r * np.sin(phi) * np.sin(theta)
        z = r * np.cos(phi)
        
        cluster_point = center + np.array([x, y, z])
        cluster_points.append(cluster_point)
    
    return cluster_points

for file in os.listdir('/Users/brendonuzoigwe/spherical-mds/new_data/non_hamiltonian_medium_mat'):
    if len(os.listdir('/Users/brendonuzoigwe/spherical-mds/cluster_data')) == 4000:
        break
    open('adjacency_list.txt', 'w').close()
    adjacency_list = parseNpyEntry(f'/Users/brendonuzoigwe/spherical-mds/new_data/non_hamiltonian_medium_mat/{file}')
    os.system('python3 layout.py adjacency_list.txt')

    def convert_js_to_json(js_file):
        with open(js_file, 'r') as file:
            content = file.read()
            content = re.sub(r'^\s*G\s*=\s*', '', content, flags=re.MULTILINE)
            json_content = content.replace("'", '"')
        return json_content

    js_file = 'webapp/data.js'
    json_content = convert_js_to_json(js_file)

    G = json.loads(json_content)
    positions = np.array([lat_long_to_cartesian(node['pos'][0], node['pos'][1]) for node in G['nodes']])

    graph_data = []

    # Add node clusters
    num_cluster_points = 10
    for pos in positions:
        graph_data.append(pos)
        cluster_points = generate_node_cluster(pos, num_cluster_points)
        graph_data.extend(cluster_points)

    num_nodes = len(G['nodes'])
    num_edges = len(G['edges'])
    if num_edges + num_nodes + num_cluster_points * num_nodes <= 2048:
        save_dir = '/Users/brendonuzoigwe/spherical-mds/cluster_data'
    else:
        continue
    
    num_edge_points = (2048 - num_nodes - num_cluster_points * num_nodes) // num_edges
    first = True

    for edge in G['edges']:
        node1 = int(edge['source'])
        node2 = int(edge['target'])
        
        if node1 < len(positions) and node2 < len(positions):
            point1 = positions[node1]
            point2 = positions[node2]
            
            if first:
                temp_point = num_edge_points + ((2048 - num_nodes) % num_edges)
                num_edge_points = temp_point
                first = False
            else:
                num_edge_points = (2048 - num_nodes) // num_edges
            
            interpolated_points = interpolate_great_circle(point1, point2, num_edge_points)
            graph_data.extend(interpolated_points)

    graph_data = np.array(graph_data)

    file_name = os.path.splitext(file)[0] + '_medium.h5'
    file_path = os.path.join(save_dir, file_name)

    with h5py.File(file_path, 'w') as h5file:
        h5file.create_dataset('data', data=graph_data)
        h5file.create_dataset('labels', data=1)
    
    open('adjacency_list.txt', 'w').close()

print(len(os.listdir('/Users/brendonuzoigwe/spherical-mds/cluster_data')))

# %%
# !python layout.py adjacency_list.txt

# %%
# !python layout.py adjacency_list.txt

# %%
import h5py
import numpy as np
import os
import json
import re
from convert import parseNpyEntry

# Define a base directory that can be adjusted as needed
BASE_DIR = os.path.abspath("/Users/brendonuzoigwe/spherical-mds")


def convert_js_to_json(js_file):
    """Convert a .js file with single quotes into valid JSON."""
    with open(js_file, 'r') as file:
        content = file.read()
        
        # Remove the variable declaration (if present) and replace single quotes with double quotes
        content = re.sub(r'^\s*G\s*=\s*', '', content, flags=re.MULTILINE)
        json_content = content.replace("'", '"')
        
    return json_content

def lat_long_to_cartesian(lat, long, radius=1.0):
    """Convert latitude and longitude to cartesian coordinates."""
    lat_rad = np.radians(lat)
    long_rad = np.radians(long)
    x = radius * np.cos(lat_rad) * np.cos(long_rad)
    y = radius * np.cos(lat_rad) * np.sin(long_rad)
    z = radius * np.sin(lat_rad)
    return [x, y, z]

def process_files(data_dir, save_dir, label):
    """Process files from a directory and save to an H5 file with specified label."""
    for file in os.listdir(data_dir):
        # Clear and recreate adjacency list file
        open('adjacency_list.txt', 'w').close()
        
        # Parse adjacency list
        adjacency_list = parseNpyEntry(os.path.join(data_dir, file))
        
        # Run layout.py on the generated adjacency list
        os.system('python3 layout.py adjacency_list.txt')
        
        # Read and convert JS file to JSON
        js_file = os.path.join(BASE_DIR, 'webapp', 'data.js')
        json_content = convert_js_to_json(js_file)
        G = json.loads(json_content)
        
        # Convert node positions
        positions = np.array([lat_long_to_cartesian(node['pos'][0], node['pos'][1]) for node in G['nodes']])
        
        # Collect all node positions initially
        graph_data = list(positions)
        
        num_nodes = len(G['nodes'])
        num_edges = len(G['edges'])
        
        # Ensure output has exactly 2048 points
        num_edge_points = 2048 - num_nodes
        points_per_edge = num_edge_points // num_edges if num_edges > 0 else 0
        extra_points = num_edge_points % num_edges if num_edges > 0 else 0

        # Create edge points
        first_edge = True
        for edge in G['edges']:
            node1 = int(edge['source'])
            node2 = int(edge['target'])
            
            # Ensure indices are valid
            if node1 < len(positions) and node2 < len(positions):
                point1 = positions[node1]
                point2 = positions[node2]
                
                # Adjust the number of points for the first edge if extra points remain
                edge_points = points_per_edge + (1 if first_edge and extra_points > 0 else 0)
                first_edge = False

                for t in np.linspace(0, 1, edge_points, endpoint=False):
                    interpolated_point = point1 * (1 - t) + point2 * t
                    graph_data.append(interpolated_point)
        
        # Ensure graph_data has exactly 2048 points
        while len(graph_data) < 2048:
            graph_data.append(graph_data[-1])  # Repeat last point to reach 2048
        graph_data = np.array(graph_data[:2048])
        
        # Save data to H5 file
        file_name = os.path.splitext(file)[0] + '.h5'
        file_path = os.path.join(save_dir, file_name)
        with h5py.File(file_path, 'w') as h5file:
            h5file.create_dataset('data', data=graph_data)
            h5file.create_dataset('labels', data=label)
        
        open('adjacency_list.txt', 'w').close()

# Define directories to process
data_dirs = [
    ('new_data/hamiltonian_small_mat', 'more_data/small/hamiltonian', 1),
    ('new_data/non_hamiltonian_small_mat', 'more_data/small/non_hamiltonian', 2),
    ('new_data/hamiltonian_medium_mat', 'more_data/medium/hamiltonian', 1),
    ('new_data/non_hamiltonian_medium_mat', 'more_data/medium/non_hamiltonian', 2),
]

# Process each directory
for data_dir, save_dir, label in data_dirs:
    process_files(os.path.join(BASE_DIR, data_dir), os.path.join(BASE_DIR, save_dir), label)
